# %%
import requests
import pandas as pd
from datetime import datetime
import time

# %%
import requests

url = "https://data-api.polymarket.com/event/super-bowl-champion-2026-731"

r = requests.get(url)
r
# Out:
# <Response [404]>
